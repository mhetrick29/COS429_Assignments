# %%
from test_face_classifier import test_face_classifier
from hog36 import hog36

# %%
test_face_classifier(6000, 1000, 9, True)

# %%
test_face_classifier(6000, 1000, 9, False)
